# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
# from sklearn.preprocessing import StandardScaler
# from sklearn.decomposition import PCA

# %%
data = {
    'AnnualIncome': [
        15,16,17,18,19,
        85,88,90,92,95,
        40,42,43,45,47
    ],

    'SpendingScore': [
        20,22,19,18,25,
        90,92,88,95,93,
        55,50,58,52,60
    ]
}

df = pd.DataFrame(data)

print(df)
# Out:
#     AnnualIncome  SpendingScore
# 0             15             20
# 1             16             22
# 2             17             19
# 3             18             18
# 4             19             25
# 5             85             90
# 6             88             92
# 7             90             88
# 8             92             95
# 9             95             93
# 10            40             55
# 11            42             50
# 12            43             58
# 13            45             52
# 14            47             60

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   AnnualIncome   15 non-null     int64
#  1   SpendingScore  15 non-null     int64
# dtypes: int64(2)
# memory usage: 372.0 bytes

# %%
df.isnull().sum()
# Out:
# AnnualIncome     0
# SpendingScore    0
# dtype: int64

# %%
# converting array
X = df[['AnnualIncome','SpendingScore']]
print(X)
# Out:
#     AnnualIncome  SpendingScore
# 0             15             20
# 1             16             22
# 2             17             19
# 3             18             18
# 4             19             25
# 5             85             90
# 6             88             92
# 7             90             88
# 8             92             95
# 9             95             93
# 10            40             55
# 11            42             50
# 12            43             58
# 13            45             52
# 14            47             60

# %%
# implementing k-mean
kmeans = KMeans(n_clusters=3, random_state=0)
kmeans.fit(X)
df['Cluster']=kmeans.predict(X)

# %%
df
# Out:
#     AnnualIncome  SpendingScore  Cluster
# 0             15             20        1
# 1             16             22        1
# 2             17             19        1
# 3             18             18        1
# 4             19             25        1
# 5             85             90        0
# 6             88             92        0
# 7             90             88        0
# 8             92             95        0
# 9             95             93        0
# 10            40             55        2
# 11            42             50        2
# 12            43             58        2
# 13            45             52        2
# 14            47             60        2

# %%
from seaborn.rcmod import palettes
# lets scatter plato to see visual
plt.scatter(df['AnnualIncome'],df['SpendingScore'])
plt.xlabel('Annual Income')
plt.ylabel('Spending Score')
plt.title('Scatter Plot of Annual Income vs Spending Score')
plt.show()

# %%
plt.figure(figsize=(8,5))

sns.scatterplot(
    x='AnnualIncome',
    y='SpendingScore',
    hue='Cluster',
    data=df,
    palette='deep',
    s=100
)

plt.title("Customer Segments")

plt.show()
